# %% [markdown]
# # Week 4 - Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# ### A description of the problem and a discussion of the background. (15 marks)

# %% [markdown]
# Japanese social security budget facing to blowing and it makes pressure as tax for Japanese public. Mainly these cause of that is depend on the aging of the population. 1/4 of Japanese public will be over age 65 in 2015. And Japanese population had a peak and it depend on borning just several years after world war-2. We call "Dankai no sedai". And second peak is "Dankai junior". On the other hand average of life is improved by suitable medical care. So aging population going up and social security expense growing up depend on that medical budget. Japan is one of an everyone insurance company. Then this situation squeezes government medical budget. So I'd like to summarize these kinds of data and make sure a suitable policy.

# %% [markdown]
# ### A description of the data and how it will be used to solve the problem. (15 marks)

# %% [markdown]
# Get data from Japanese Cabinet Office site. These data was guaranteed by government. Pick up these data and make sure relation of several parameter. Typical relation is already discussed but more detail analysis will be help for further discussion. Then make sure solution of these promblem.¶
# https://www8.cao.go.jp/kourei/ishiki/h24/kenkyu/zentai/csv.html
# https://www.e-stat.go.jp/stat-search/database?page=1&toukei=00450012&tstat=000001031336

# %% [markdown]
# # Week 5 - The Battle of Neighborhoods (Cont'd)  In this week, you will continue working on your capstone project. Please remember by the end of this week, you will need to submit the following:

# %% [markdown]
# ### 1. A full report consisting of all of the following components (15 marks):
# Introduction where you discuss the business problem and who would be interested in this project.
# Data where you describe the data that will be used to solve the problem and the source of the data.
# Methodology section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, if any, and what machine learnings were used and why.
# Results section where you discuss the results.
# Discussion section where you discuss any observations you noted and any recommendations you can make based on the results.
# Conclusion section where you conclude the report.

# %% [markdown]
# # Japanese Medical Expence Budget

# %%
import matplotlib.pyplot as plt
import pandas as pd
url = "https://www5.cao.go.jp/keizai-shimon/kaigi/special/reform/mieruka/data/p2/p2_02.csv"
# names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
# data = pandas.read_csv(url, names=names)
# data.plot(kind='density', subplots=True, layout=(3,3), sharex=False)
# plt.show()
df = pd.read_csv(url,encoding="SHIFT-JIS")

# %%
print(df.head()).head()
# Out:
#   「見える化」項目 医療費（市町村国保）  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0    数値の単位         千円         NaN         NaN         NaN         NaN
# 1      NaN        NaN         NaN         NaN         NaN         NaN
# 2    地域コード        地域名      1975.0      1976.0      1977.0      1978.0
# 3     1000        北海道         NaN         NaN         NaN         NaN
# 4     2000        青森県         NaN         NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 38  \
# 0         NaN         NaN         NaN         NaN  ...          NaN
# 1         NaN         NaN         NaN         NaN  ...          NaN
# 2      1979.0      1980.0      1981.0      1982.0  ...       2011.0
# 3         NaN         NaN         NaN         NaN  ...  524742184.1
# 4         NaN         NaN         NaN         NaN  ...  131421625.1
#
#    Unnamed: 39  Unnamed: 40  Unnamed: 41  Unnamed: 42  Unnamed: 43  \
# ...

# %%
df.head()
# Out:
#   「見える化」項目 医療費（市町村国保）  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0    数値の単位         千円         NaN         NaN         NaN         NaN
# 1      NaN        NaN         NaN         NaN         NaN         NaN
# 2    地域コード        地域名      1975.0      1976.0      1977.0      1978.0
# 3     1000        北海道         NaN         NaN         NaN         NaN
# 4     2000        青森県         NaN         NaN         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 38  \
# 0         NaN         NaN         NaN         NaN  ...          NaN
# 1         NaN         NaN         NaN         NaN  ...          NaN
# 2      1979.0      1980.0      1981.0      1982.0  ...       2011.0
# 3         NaN         NaN         NaN         NaN  ...  524742184.1
# 4         NaN         NaN         NaN         NaN  ...  131421625.1
#
#    Unnamed: 39  Unnamed: 40  Unnamed: 41  Unnamed: 42  Unnamed: 43  \
# ...

# %%
df.drop(range(0,2),inplace=True)

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.columns
# Out:
# Index(['「見える化」項目', '医療費（市町村国保）', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
#        'Unnamed: 46', 'Unnamed: 47'],
#       dtype='object')

# %%
df.drop(columns=['「見える化」項目','医療費（市町村国保）','Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
       'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
       'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
       'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
       'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
       'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24','Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
       'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32','Unnamed: 33', 'Unnamed: 34', 'Unnamed: 42',
       'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  Unnamed: 39  \
# 2       2008.0       2009.0       2010.0       2011.0       2012.0
# 3  499417914.6  504064877.7  514992357.7  524742184.1  524595447.5
# 4  129324312.7  129582441.7  130333391.3  131421625.1  130015007.7
# 5  108799620.6  111564032.8  112090678.7  114330656.7  116524914.6
# 6  176074611.8  180325210.7  184892721.0  192050977.2  203398216.3
#
#    Unnamed: 40  Unnamed: 41
# 2       2013.0       2014.0
# 3  526738249.7  518356581.4
# 4  129240667.0  127402762.1
# 5  115802473.4  113673484.2
# 6  195649359.1  194288077.1

# %%
df_int = df.astype('int64')

# %%
print(type(df_int))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
x = df_int.iloc[0]

# %%
print(x)
# Out:
# Unnamed: 35    2008
# Unnamed: 36    2009
# Unnamed: 37    2010
# Unnamed: 38    2011
# Unnamed: 39    2012
# Unnamed: 40    2013
# Unnamed: 41    2014
# Name: 2, dtype: int64

# %%
df_int.head()
# Out:
#    Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  Unnamed: 39  \
# 2         2008         2009         2010         2011         2012
# 3    499417914    504064877    514992357    524742184    524595447
# 4    129324312    129582441    130333391    131421625    130015007
# 5    108799620    111564032    112090678    114330656    116524914
# 6    176074611    180325210    184892721    192050977    203398216
#
#    Unnamed: 40  Unnamed: 41
# 2         2013         2014
# 3    526738249    518356581
# 4    129240667    127402762
# 5    115802473    113673484
# 6    195649359    194288077

# %%
df_data=df.drop(df.index[[0]])
df_int = df_data.astype('int64')
df_int.head()
# Out:
#    Unnamed: 35  Unnamed: 36  Unnamed: 37  Unnamed: 38  Unnamed: 39  \
# 3    499417914    504064877    514992357    524742184    524595447
# 4    129324312    129582441    130333391    131421625    130015007
# 5    108799620    111564032    112090678    114330656    116524914
# 6    176074611    180325210    184892721    192050977    203398216
# 7     95191784     96666872     97110546     97726018     97451904
#
#    Unnamed: 40  Unnamed: 41
# 3    526738249    518356581
# 4    129240667    127402762
# 5    115802473    113673484
# 6    195649359    194288077
# 7     98540229     97586186

# %%
y=df_int.sum(axis=0)/1000000000

# %%
print(y)
# Out:
# Unnamed: 35    10.198533
# Unnamed: 36    10.452858
# Unnamed: 37    10.730827
# Unnamed: 38    10.993981
# Unnamed: 39    11.102115
# Unnamed: 40    11.212273
# Unnamed: 41    11.249197
# dtype: float64

# %% [markdown]
# # Social Medical Expence Budget Graph

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6), dpi=100)
plt.xlabel('Year')
plt.ylabel('Trillion JPY/Year')
plt.title('Social Security Budget')
plt.ylim([0,15])
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Population Growth

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    元号  和暦（年）   西暦（年）  年齢5歳階級      人口（総数）       人口（男）       人口（女）
# 0  大正    9.0  1920.0      総数  55963053.0  28044185.0  27918868.0
# 1  大正    9.0  1920.0    0〜4歳   7457715.0   3752627.0   3705088.0
# 2  大正    9.0  1920.0    5〜9歳   6856920.0   3467156.0   3389764.0
# 3  大正    9.0  1920.0  10〜14歳   6101567.0   3089225.0   3012342.0
# 4  大正    9.0  1920.0  15〜19歳   5419057.0   2749022.0   2670035.0
# 5  大正    9.0  1920.0  20〜24歳   4609310.0   2316479.0   2292831.0
# 6  大正    9.0  1920.0  25〜29歳   3923949.0   2008005.0   1915944.0
# 7  大正    9.0  1920.0  30〜34歳   3609450.0   1833443.0   1776007.0
# 8  大正    9.0  1920.0  35〜39歳   3410738.0   1707771.0   1702967.0
# 9  大正    9.0  1920.0  40〜44歳   3243764.0   1640254.0   1603510.0

# %%
df_data_2.shape
# Out:
# (406, 7)

# %%
df_data_2.head()
# Out:
#    元号  和暦（年）   西暦（年）  年齢5歳階級      人口（総数）       人口（男）       人口（女）
# 0  大正    9.0  1920.0      総数  55963053.0  28044185.0  27918868.0
# 1  大正    9.0  1920.0    0〜4歳   7457715.0   3752627.0   3705088.0
# 2  大正    9.0  1920.0    5〜9歳   6856920.0   3467156.0   3389764.0
# 3  大正    9.0  1920.0  10〜14歳   6101567.0   3089225.0   3012342.0
# 4  大正    9.0  1920.0  15〜19歳   5419057.0   2749022.0   2670035.0

# %%
df_data_2= df_data_2.drop('元号', axis=1)

# %%
df_data_3= df_data_2.drop('和暦（年）', axis=1)

# %%
df_data_3= df_data_3.drop('人口（男）', axis=1)

# %%
df_data_3= df_data_3.drop('人口（女）', axis=1)

# %%
df_data_3= df_data_3.drop(range(395,406))

# %%
df_data_3
# Out:
#       西暦（年）    年齢5歳階級       人口（総数）
# 0    1920.0        総数   55963053.0
# 1    1920.0      0〜4歳    7457715.0
# 2    1920.0      5〜9歳    6856920.0
# 3    1920.0    10〜14歳    6101567.0
# 4    1920.0    15〜19歳    5419057.0
# 5    1920.0    20〜24歳    4609310.0
# 6    1920.0    25〜29歳    3923949.0
# 7    1920.0    30〜34歳    3609450.0
# 8    1920.0    35〜39歳    3410738.0
# 9    1920.0    40〜44歳    3243764.0
# 10   1920.0    45〜49歳    2658567.0
# 11   1920.0    50〜54歳    2234762.0
# 12   1920.0    55〜59歳    1840093.0
# 13   1920.0    60〜64歳    1655805.0
# 14   1920.0    65〜69歳    1312537.0
# 15   1920.0    70〜74歳     896618.0
# 16   1920.0    75〜79歳     482012.0
# 17   1920.0    80〜84歳     174183.0
# 18   1920.0     85歳以上      76006.0
# 19   1925.0        総数   59736822.0
# 20   1925.0      0〜4歳    8264583.0
# 21   1925.0      5〜9歳    6924432.0
# 22   1925.0    10〜14歳    6735030.0
# 23   1925.0    15〜19歳    5885277.0
# 24   1925.0    20〜24歳    5060527.0
# 25   1925.0    25〜29歳    4393471.0
# ...

# %%
df_data_4=df_data_3[df_data_3["年齢5歳階級"].isin(["65〜69歳", "70〜74歳","75〜79歳","80〜84歳","85〜89歳","90〜94歳","95〜99歳","100〜104歳","105〜109歳","110歳以上","85歳以上"])]

# %%
x2 =[]
y2 =[]
for i in range(1920, 2020,5):
    x2.append(i)
    y2.append((df_data_4[df_data_4["西暦（年）"] == i]["人口（総数）"].sum())/1000000)

# %% [markdown]
# # Population over 65years old in Japan

# %%
plt.figure(figsize=(10, 6), dpi=100)
plt.xlabel('Year')
plt.ylabel('Million JPY/Year')
plt.title('Population over 65years old')
plt.ylim([0,40])
plt.plot(x2,y2)

plt.show()

# %% [markdown]
# ### 2. A link to your Notebook on your Github repository pushed showing your code. (15 marks)

# %% [markdown]
# ### 3. Your choice of a presentation or blogpost. (10 marks)
